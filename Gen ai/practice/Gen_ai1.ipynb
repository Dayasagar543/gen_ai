# %% [markdown]
# # python

# %% [markdown]
# ## python introduction

# %% [markdown]
# python is a programming language which is used to communicate with computer .

# %%
a=23;b=34;c=45
sum=a+b+c
print(sum)
# Out:
# 102

# %%
if -1:
    print("hi ")
# Out:
# hi

# %%
if 0:
    print("there")

# %%
if 1:
    print("king")
# Out:
# king

# %%
name="Amith"
Name="Amith"
name==Name
# Out:
# True

# %%
values=list((1,2,4,5,6,7,8,8,12,0,8,76))
values
# Out:
# [1, 2, 4, 5, 6, 7, 8, 8, 12, 0, 8, 76]

# %%
for i in values[::-1]:
    print(i)
# Out:
# 76
# 8
# 0
# 12
# 8
# 8
# 7
# 6
# 5
# 4
# 2
# 1

# %%
name="rahul"
print(name[::-1])
name1="ravi"
print(name1[::-1])
# Out:
# luhar
# ivar
